# %%
import regression_task as rg
import numpy as np

# %%
import data_cleaner as d

# %%
x_train, y_train, x_test, y_test = d.get_data("linear")

# %%
y = rg.Regression_model(rg.Linear_reg, 1)

# %%
x_train, y_train, x_test, y_test = d.get_data("logistic")

# %%
y = rg.Regression_model(rg.Logistic_reg, 8)

# %%
y.train(x_train, y_train, 0.01, 10, 6)
# Out:
# Iteration  0
# Current Cost:  12.3472436758
# Iteration  1
# Current Cost:  11.4511941497
# Iteration  2
# Current Cost:  8.91031767933
# Iteration  3
# Current Cost:  6.08130300009
# Epoch  1  	Complete
# Iteration  0
# Current Cost:  6.27624976484
# Iteration  1
# Current Cost:  6.08114376343
# Iteration  2
# Current Cost:  5.33647956876
# Iteration  3
# Current Cost:  4.55570573335
# Epoch  2  	Complete
# Iteration  0
# Current Cost:  4.66462633033
# Iteration  1
# Current Cost:  4.63484153917
# Iteration  2
# Current Cost:  4.40000759827
# Iteration  3
# Current Cost:  4.17874690678
# Epoch  3  	Complete
# Iteration  0
# Current Cost:  4.23423724756
# Iteration  1
# Current Cost:  4.2379150031
# Iteration  2
# Current Cost:  4.15584923387
# Iteration  3
# Current Cost:  4.09173577139
# Epoch  4  	Complete
# Iteration  0
# Current Cost:  4.1173436066
# Iteration  1
# Current Cost:  4.12461761978
# Iteration  2
# Current Cost:  4.09218877422
# Iteration  3
# ...

# %%
y.test(x_test, y_test)
